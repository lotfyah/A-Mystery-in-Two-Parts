# %%
# dependencies and setup

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from sqlalchemy import create_engine
engine = create_engine('postgresql://postgres:Password@localhost:5432/EmployeeDB')
connection = engine.connect()

# %%
# read salary data from SQL
salary_data = pd.read_sql("select * from salaries",connection)
salary_data
# Out:
#         emp_no  salary
# 0        10001   60117
# 1        10002   65828
# 2        10003   40006
# 3        10004   40054
# 4        10005   78228
# ...        ...     ...
# 300019  499995   40000
# 300020  499996   58058
# 300021  499997   49597
# 300022  499998   40000
# 300023  499999   63707
#
# [300024 rows x 2 columns]

# %%
# histogram to visualize the common salary for employees
plt.hist(salary_data['salary'], density=False, label="salary")
plt.axvline(salary_data['salary'].mean(), color='r', label="average salary")
plt.xlabel("salaries")
plt.ylabel("number of employees")
plt.legend() 
plt.title("salary range")
plt.savefig("salary_range_hist.png")

# %%
# read title data from SQL
title_data = pd.read_sql("select * from titles", connection)
title_data
# Out:
#   title_id               title
# 0    s0001               Staff
# 1    s0002        Senior Staff
# 2    e0001  Assistant Engineer
# 3    e0002            Engineer
# 4    e0003     Senior Engineer
# 5    e0004    Technique Leader
# 6    m0001             Manager

# %%
# read employees data from SQL
employees_data = pd.read_sql("select * from employees", connection)
employees_data
# Out:
#         emp_no emp_title  birth_date   first_name  last_name sex   hire_date
# 0       473302     s0001  1953-07-25     Hideyuki   Zallocco   M  1990-04-28
# 1       475053     e0002  1954-11-18        Byong  Delgrande   F  1991-09-07
# 2        57444     e0002  1958-01-30        Berry       Babb   F  1992-03-21
# 3       421786     s0001  1957-09-28        Xiong   Verhoeff   M  1987-11-26
# 4       282238     e0003  1952-10-28   Abdelkader    Baumann   F  1991-01-18
# ...        ...       ...         ...          ...        ...  ..         ...
# 300019  464231     s0001  1958-08-14  Constantino    Eastman   M  1988-10-28
# 300020  255832     e0002  1955-05-08       Yuping     Dayang   F  1995-02-26
# 300021   76671     s0001  1959-06-09       Ortrud   Plessier   M  1988-02-24
# 300022  264920     s0001  1959-09-22        Percy   Samarati   F  1994-09-08
# 300023  464503     s0002  1964-05-31       Arvind  Slobodova   M  1987-11-23
#
# [300024 rows x 7 columns]

# %%
# join salary data with employees data then with title data since no direct connection between salary and title
merged_df = pd.read_sql("select * from employees e join salaries s on e.emp_no = s.emp_no join titles t on e.emp_title = t.title_id", connection)
merged_df
# Out:
#         emp_no emp_title  birth_date first_name    last_name sex   hire_date  \
# 0        10005     s0001  1955-01-21    Kyoichi     Maliniak   M  1989-09-12
# 1        10010     e0002  1963-06-01  Duangkaew     Piveteau   F  1989-08-24
# 2        10011     s0001  1953-11-07       Mary        Sluis   F  1990-01-22
# 3        10013     s0002  1963-06-07  Eberhardt       Terkki   M  1985-10-20
# 4        10017     s0001  1958-07-06  Cristinel    Bouloucos   F  1993-08-03
# ...        ...       ...         ...        ...          ...  ..         ...
# 300019  499948     e0002  1953-05-24   Cordelia    Paludetto   M  1993-01-28
# 300020  499972     e0003  1957-07-25     Katsuo       Leuchs   F  1989-11-23
# 300021  499985     s0001  1964-12-26       Gila  Lukaszewicz   M  1997-02-11
# 300022  499987     s0001  1961-09-05      Rimli       Dusink   F  1998-09-20
# 300023  499998     s0001  1956-09-05   Patricia      Breugel   M  1993-10-13
#
# ...

# %%
# average salary by title 
Avg_salary_by_title = merged_df.groupby(['title']).mean()['salary']
Avg_salary_by_title
# Out:
# title
# Assistant Engineer    48564.434447
# Engineer              48535.336511
# Manager               51531.041667
# Senior Engineer       48506.799871
# Senior Staff          58550.172704
# Staff                 58465.382850
# Technique Leader      48582.896092
# Name: salary, dtype: float64

# %%
# Bar chart for average salary by title
plot1 = Avg_salary_by_title.plot(kind="bar", title="average salary by title")
plot1.set_xlabel("title")
plot1.set_ylabel("average salary")
plt.savefig("average salary by title.png")
plt.show()
